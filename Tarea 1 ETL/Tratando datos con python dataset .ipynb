# %% [markdown]
# ## Importando Librerias

# %%
import numpy as pd
import pandas as pd

# %% [markdown]
# ## Cargando dataset

# %%
dataset = pd.read_csv("dataset1.csv")

#Analisis Exploratorio

dataset
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Explorando dataset

# %% [markdown]
# ### Branch - Rama

# %%
branch_data = dataset.groupby('Branch').size()
branch_data
# Out:
# Branch
# A    340
# B    332
# C    328
# dtype: int64

# %% [markdown]
# ### City - Ciudad

# %%
city_data = dataset.groupby('City').size()
city_data
# Out:
# City
# Mandalay     332
# Naypyitaw    328
# Yangon       340
# dtype: int64

# %% [markdown]
# ### Customer Type - Tipo cliente

# %%
customer_data = dataset.groupby('Customer type').size()
customer_data
# Out:
# Customer type
# Member    501
# Normal    499
# dtype: int64

# %% [markdown]
# ### Product Line - Linea producto

# %%
productline_data = dataset.groupby('Product line').size()
productline_data
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# dtype: int64

# %% [markdown]
# ### Payment - Tipo Pago

# %%
payment_data = dataset.groupby('Payment').size()
payment_data
# Out:
# Payment
# Cash           344
# Credit card    311
# Ewallet        345
# dtype: int64

# %% [markdown]
# ### Gender - Genero

# %%
gender_data = dataset.groupby('Gender').size()
gender_data
# Out:
# Gender
# Female    501
# Male      499
# dtype: int64

# %% [markdown]
# # Exploracion adicional de datos

# %%
dataset
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#El total esta bien sumado
for i in range(0, 1000, 1):
    #print("Precio unitario: ", dataset['Unit price'][i], " Cantidad : ",dataset['Quantity'][i], " + 5% Tax :", dataset['Tax 5%'][i], " Total = ", dataset['Total'][i])
    total_sum = ((float(dataset['Unit price'][i])*float(dataset['Quantity'][i])) + float(dataset['Tax 5%'][i]))
    #print("Total sumado = ", total_sum)
    #print("Iteracion :",i," Total_sum = Total ? ",int(total_sum) == int(dataset['Total'][i]) )
    if((int(total_sum) != int(dataset['Total'][i])) ):
        print("Existe un valor que no es igual")

# %% [markdown]
# ### Explorando precio unitario

# %%
unitprice_data = dataset.groupby('Unit price').size()
unitprice_data # No es muy relevante
# Out:
# Unit price
# 10.08    1
# 10.13    1
# 10.16    1
# 10.17    1
# 10.18    1
#         ..
# 99.82    2
# 99.83    1
# 99.89    1
# 99.92    1
# 99.96    2
# Length: 943, dtype: int64

# %% [markdown]
# ### Explorando COGS - o Calculo Costo de Bienes Vendidos

# %%
cogs_data = dataset.groupby('cogs').size() # Encontramos muchos valores cambiantes, no relevante.
cogs_data
# Out:
# cogs
# 10.17     1
# 12.09     1
# 12.54     1
# 12.78     1
# 13.98     1
#          ..
# 973.80    1
# 975.00    1
# 985.20    1
# 989.80    1
# 993.00    1
# Length: 990, dtype: int64

# %% [markdown]
# ## Explorando Fecha --> Postressql orden AAAA-MM-DD

# %%
date_splited = dataset['Date'][0].split('/')
new_order = date_splited[1]+"-"+date_splited[0]+"-"+date_splited[2]
print(new_order)
# Out:
# 5-1-2019

# %% [markdown]
# ## Definiendo funciones de transformacion

# %%
# Funcion para cambiar los valores de gender
def change_gender(val):
    if (val == 'Male'):
        return 'Masculino'
    else:
        return 'Femenino'

# Funcion para cambiar los valores de customer_type
def change_customer(val):
    if(val == 'Member'):
        return 'Miembro'
    else:
        return 'Normal'
    
# Funcion para cambiar los valores de Product Line
def change_product(val):
    if(val == 'Electronic accessories'): # Accesorios electronicos
        return 'Accesorios Electronicos'
    elif(val == 'Fashion accessories'): # Accesorios de moda
        return 'Accesorios Moda'
    elif(val == 'Food and beverages'): #Comida y bebidas
        return 'Alimentos y Bebidas'
    elif(val == 'Health and beauty'): # Salud y belleza
        return 'Salud y Belleza'
    elif(val == 'Home and lifestyle'): # Casa y estilo de vida
        return 'Hogar y Estilo De Vida'
    elif(val == 'Sports and travel'): # Deportes y viajes
        return 'Deportes y Viajes'
    else:
        return 'Valor Erroneo'

# Funcion para cambiar los valores de Payment
def change_payment(val):
    if(val == 'Cash'):
        return 'Efectivo'
    elif(val == 'Credit card'):
        return 'Tarjeta de Credito'
    elif(val == 'Ewallet'):
        return 'Billetera electronica'
    
#Funcion que cambia el formato de la fecha para la columna DATE
def change_dateform(val):
    date_splited = val.split('/')
    new_order = date_splited[1]+"-"+date_splited[0]+"-"+date_splited[2]
    return new_order

# %% [markdown]
# # Dataset antes funciones de aplicacion

# %%
dataset
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Aplicando Funciones de transformacion y compiando columnas.

# %%
# Gender
dataset['Gender'] = dataset['Gender'].transform(change_gender)

# customer type
dataset['Customer type'] = dataset['Customer type'].transform(change_customer)

# Product line
dataset['Product line'] = dataset['Product line'].transform(change_product)

# Payment
dataset['Payment'] = dataset['Payment'].transform(change_payment)

#Date
dataset['Date'] = dataset['Date'].transform(change_dateform)

dataset
# Out:
#       Invoice ID Branch       City Customer type     Gender  \
# 0    750-67-8428      A     Yangon       Miembro   Femenino
# 1    226-31-3081      C  Naypyitaw        Normal   Femenino
# 2    631-41-3108      A     Yangon        Normal  Masculino
# 3    123-19-1176      A     Yangon       Miembro  Masculino
# 4    373-73-7910      A     Yangon        Normal  Masculino
# ..           ...    ...        ...           ...        ...
# 995  233-67-5758      C  Naypyitaw        Normal  Masculino
# 996  303-96-2227      B   Mandalay        Normal   Femenino
# 997  727-02-1313      A     Yangon       Miembro  Masculino
# 998  347-56-2442      A     Yangon        Normal  Masculino
# 999  849-09-3807      A     Yangon       Miembro   Femenino
#
#                 Product line  Unit price  Quantity   Tax 5%      Total  \
# 0            Salud y Belleza       74.69         7  26.1415   548.9715
# 1    Accesorios Electronicos       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Revisamos que todos los cambios se haya hecho y no hayan errores

# %%
customer_data = dataset.groupby('Customer type').size()
customer_data
# Out:
# Customer type
# Miembro    501
# Normal     499
# dtype: int64

# %%
productline_data = dataset.groupby('Product line').size()
productline_data
# Out:
# Product line
# Accesorios Electronicos    170
# Accesorios Moda            178
# Alimentos y Bebidas        174
# Deportes y Viajes          166
# Hogar y Estilo De Vida     160
# Salud y Belleza            152
# dtype: int64

# %%
gender_data = dataset.groupby('Gender').size()
gender_data
# Out:
# Gender
# Femenino     501
# Masculino    499
# dtype: int64

# %%
payment_data = dataset.groupby('Payment').size()
payment_data
# Out:
# Payment
# Billetera electronica    345
# Efectivo                 344
# Tarjeta de Credito       311
# dtype: int64

# %% [markdown]
# ## Todo correcto procedemos a hacer la extraccion de datos

# %% [markdown]
# ### Extrayendo columnas

# %%
#Nombre de las cabeceras del data set
columnas2 = dataset[
    ['Invoice ID',
     'Branch',
     'City',
     'Customer type',
     'Gender',
     'Product line',
     'Unit price',
     'Quantity',
     'Tax 5%',
     'Total',
     'Date',
     'Time',
     'Payment',
     'cogs',
     'gross margin percentage',
     'gross income',
     'Rating']].columns.values

columnas_eng = []
j = 0
for i in columnas2:
    j = j +1
    print(j," --> ",i)
    columnas_eng.append(i)
# Out:
# 1  -->  Invoice ID
# 2  -->  Branch
# 3  -->  City
# 4  -->  Customer type
# 5  -->  Gender
# 6  -->  Product line
# 7  -->  Unit price
# 8  -->  Quantity
# 9  -->  Tax 5%
# 10  -->  Total
# 11  -->  Date
# 12  -->  Time
# 13  -->  Payment
# 14  -->  cogs
# 15  -->  gross margin percentage
# 16  -->  gross income
# 17  -->  Rating

# %%
columnas_esp = [
    'ID Factura',
    'Rama',
    'Ciudad',
    'Tipo Cliente',
    'Genero',
    'Linea Producto',
    'Precio Unitario',
    'Cantidad',
    'Impuesto 5%',
    'Total',
    'Fecha',
    'Hora',
    'Tipo Pago',
    'COBV',
    'Porcentaje Margen Bruto',
    'Porcentaje Ingreso',
    'Calificacion'
]

j = 0
for i in columnas_esp:
    j = j +1
    print(j," --> ",i)
# Out:
# 1  -->  ID Factura
# 2  -->  Rama
# 3  -->  Ciudad
# 4  -->  Tipo Cliente
# 5  -->  Genero
# 6  -->  Linea Producto
# 7  -->  Precio Unitario
# 8  -->  Cantidad
# 9  -->  Impuesto 5%
# 10  -->  Total
# 11  -->  Fecha
# 12  -->  Hora
# 13  -->  Tipo Pago
# 14  -->  COBV
# 15  -->  Porcentaje Margen Bruto
# 16  -->  Porcentaje Ingreso
# 17  -->  Calificacion

# %%
esp_dataset = pd.DataFrame(columns = columnas_esp)
for i in range(0, len(columnas2), 1):
    print(i)
    print(columnas2[i])
    print(columnas_esp[i])
# Out:
# 0
# Invoice ID
# ID Factura
# 1
# Branch
# Rama
# 2
# City
# Ciudad
# 3
# Customer type
# Tipo Cliente
# 4
# Gender
# Genero
# 5
# Product line
# Linea Producto
# 6
# Unit price
# Precio Unitario
# 7
# Quantity
# Cantidad
# 8
# Tax 5%
# Impuesto 5%
# 9
# Total
# Total
# 10
# Date
# Fecha
# 11
# Time
# Hora
# 12
# Payment
# Tipo Pago
# 13
# cogs
# COBV
# 14
# gross margin percentage
# Porcentaje Margen Bruto
# 15
# gross income
# Porcentaje Ingreso
# 16
# Rating
# Calificacion

# %%
for i in range(0, len(columnas2), 1):
    esp_dataset[columnas_esp[i]] = dataset[columnas2[i]].copy()
esp_dataset
# Out:
#       ID Factura Rama     Ciudad Tipo Cliente     Genero  \
# 0    750-67-8428    A     Yangon      Miembro   Femenino
# 1    226-31-3081    C  Naypyitaw       Normal   Femenino
# 2    631-41-3108    A     Yangon       Normal  Masculino
# 3    123-19-1176    A     Yangon      Miembro  Masculino
# 4    373-73-7910    A     Yangon       Normal  Masculino
# ..           ...  ...        ...          ...        ...
# 995  233-67-5758    C  Naypyitaw       Normal  Masculino
# 996  303-96-2227    B   Mandalay       Normal   Femenino
# 997  727-02-1313    A     Yangon      Miembro  Masculino
# 998  347-56-2442    A     Yangon       Normal  Masculino
# 999  849-09-3807    A     Yangon      Miembro   Femenino
#
#               Linea Producto  Precio Unitario  Cantidad  Impuesto 5%  \
# 0            Salud y Belleza            74.69         7      26.1415
# 1    Accesorios Electronicos            15.28         5       3.8200
# 2     Hogar y Estilo De Vida            46.33         7      16.2155
# ...

# %% [markdown]
# ## Ordenamos Columnas

# %%
df = esp_dataset[
    [
    'ID Factura',
    'Ciudad',
    'Rama',
    'Tipo Cliente',
    'Genero',
    'Linea Producto',
    'Tipo Pago',
    'Cantidad',
    'Precio Unitario',
    'Impuesto 5%',
    'Total',
    'COBV',
    'Porcentaje Margen Bruto',
    'Porcentaje Ingreso',
    'Fecha',
    'Hora',
    'Calificacion']]

df
# Out:
#       ID Factura     Ciudad Rama Tipo Cliente     Genero  \
# 0    750-67-8428     Yangon    A      Miembro   Femenino
# 1    226-31-3081  Naypyitaw    C       Normal   Femenino
# 2    631-41-3108     Yangon    A       Normal  Masculino
# 3    123-19-1176     Yangon    A      Miembro  Masculino
# 4    373-73-7910     Yangon    A       Normal  Masculino
# ..           ...        ...  ...          ...        ...
# 995  233-67-5758  Naypyitaw    C       Normal  Masculino
# 996  303-96-2227   Mandalay    B       Normal   Femenino
# 997  727-02-1313     Yangon    A      Miembro  Masculino
# 998  347-56-2442     Yangon    A       Normal  Masculino
# 999  849-09-3807     Yangon    A      Miembro   Femenino
#
#               Linea Producto              Tipo Pago  Cantidad  \
# 0            Salud y Belleza  Billetera electronica         7
# 1    Accesorios Electronicos               Efectivo         5
# 2     Hogar y Estilo De Vida     Tarjeta de Credito         7
# ...

# %% [markdown]
# # Subida a la base de datos

# %%
import psycopg2 as pg
from psycopg2 import sql
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

def create_database(database_name, conn):
    cur = conn.cursor()
    select ="SELECT 1 FROM pg_catalog.pg_database WHERE datname = '" + database_name + "';" #Busca si la base de datos existe
    cur.execute(select)
    exists_database = cur.fetchone()#Si la lista tiene datos existe la base de datos
    if not exists_database: #Si no tiene ningun dato la base de datos no existe y tenemos que crear una
        cur.execute(sql.SQL("CREATE DATABASE {}").format(sql.Identifier(database_name)))
    return exists_database


def create_tables(cur, conn, exists):
    #En el caso de que la base de datos exista eliminamos las tablas
    if exists_database:
        cur.execute("""DROP TABLE IF EXISTS Factura;
                          DROP TABLE IF EXISTS Linea_Producto;
                          DROP TABLE IF EXISTS Ciudad;
                          DROP TABLE IF EXISTS Tipo_Pago;
                          DROP TABLE IF EXISTS Tipo_Cliente;
                          DROP TABLE IF EXISTS Genero;
                          DROP TABLE IF EXISTS Rama;""")
        conn.commit()
    #Creamos las tablas
    cur.execute("""CREATE TABLE Rama(id serial primary key, rama char(1) not null);
                      CREATE TABLE Linea_Producto(id serial primary key, linea_producto text not null);
                      CREATE TABLE Ciudad(id serial primary key, ciudad text not null);
                      CREATE TABLE Tipo_Pago(id serial primary key, tipo_pago text not null);
                      CREATE TABLE Tipo_Cliente(id serial primary key, tipo text not null);
                      CREATE TABLE Genero(id serial primary key, genero text not null);
                      CREATE TABLE Factura(id text primary key,
                                           precio_unitario double precision not null,
                                           cantidad integer not null,
                                           impuesto double precision not null,
                                           total double precision not null,
                                           fecha date not null,
                                           hora time not null,
                                           cobv double precision not null,
                                           porcentaje_margen_bruto double precision not null,
                                           porcentaje_ingreso double precision not null,
                                           calificacion double precision not null,
                                           linea_producto integer not null references Linea_Producto(id),
                                           tipo_pago integer not null references Tipo_Pago(id),
                                           tipo_cliente integer not null references Tipo_Cliente(id),
                                           genero integer not null references Genero(id),
                                           rama integer not null references Rama(id),
                                           ciudad integer not null references Ciudad(id));""")
    conn.commit()
    
conn = pg.connect(host='localhost', user='postgres', password='postgres')   
conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
database_name = "Data_Set_Supermercado"
exists_database = create_database(database_name, conn)
conn = pg.connect(host="localhost", user="postgres", password="postgres", database=database_name)
cur = conn.cursor()
create_tables(cur, conn, exists_database)
